# %%
import pandas as pd 
import numpy as np
from sklearn.cross_validation import train_test_split
from sklearn import linear_model
#import pylab as plt
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import statsmodels.api as sm
from sklearn.cross_validation import KFold
import pylab as pl
import statsmodels.tools
# %matplotlib inline

# %% [markdown]
# ##STEP 2
#
# After having obtained a prediction for the number of requests for each type of 311 service request, we are going to try calculate the relative error for the predictions and find clusters of similar errors. The goal of cluster the errors is to detect areas where the demographic features are not enough to predict the number of 311 requests and, instead, there are more features (about the neighborhood itself instead of its population) that affect the volume of 311 requests.

# %% [markdown]
# This notebook contain 4 analysis:
#
# 1) the error is calculated for each type of complain
#
# 2) We analyze first a specific case for spatial distribution of the error: service requests about 'Noise' and its spatial autocorrelation (using the Moran's I).
#
# 3) Then, we repeat the process for each type of requests, we filter for those types of requests that are statistically significant and we take the one with the highest Moran's I (that means, with the highest spatial autocorrelation) for analysis.
#
# OUTPUT: outputs/phase2_spatial_autocorrelation.csv stores the Moran's I for those types of requests with statistically significant Moran's I value for further analysis at the end of the notebook
#
# 4) Feature selection and regression is performed for those types of complains with Moran's I values greater than 0.2
#
# OUTPUTS:
#
# outputs/phase2_coefficients.csv with the coefficients obtained after running the LASSO over the features with high spatial autocorrelation
#
# outputs/phase2_predicted.csv with the predicted number of calls for the complains after running the LASSO over the features with high spatial autocorrelation

# %%
#read the prediction obtained in step1.
predicted_table=pd.read_csv('outputs/predicted_values.csv')
observed_table=pd.read_csv('outputs/observed_values.csv')
predicted_table.index=predicted_table['Unnamed: 0']
predicted_table.drop(['Unnamed: 0'],inplace=True,axis=1)
del predicted_table.index.name
observed_table.index=observed_table['Unnamed: 0']
observed_table.drop(['Unnamed: 0'],inplace=True,axis=1)
del observed_table.index.name

# %%
predicted_table.head()
# Out:
#                             Allerton-Pelham Gardens  \
# Lead                                       5.475991
# WATER LEAK                                69.619765
# Bus Stop Shelter Placement                 0.597771
# Found Property                             0.706029
# For Hire Vehicle Complaint                10.021396
#
#                             Annadale-Huguenot-Prince's Bay-Eltingville  \
# Lead                                                          6.842618
# WATER LEAK                                                   14.782818
# Bus Stop Shelter Placement                                    0.618073
# Found Property                                                0.143493
# For Hire Vehicle Complaint                                    8.533202
#
#                             Arden Heights     Astoria  Auburndale  \
# Lead                             4.953731   25.094258    4.912213
# WATER LEAK                       9.577409  355.777137   21.707367
# Bus Stop Shelter Placement       0.537218    2.679893    0.381693
# Found Property                   0.398000    1.838258    0.396765
# For Hire Vehicle Complaint       8.930713   13.658009    9.000638
#
#                             Baisley Park  Bath Beach  \
# Lead                            4.805106    7.120284
# WATER LEAK                     94.407597   90.792880
# Bus Stop Shelter Placement      0.697188    0.701274
# Found Property                  0.408955    0.559015
# For Hire Vehicle Complaint      9.374346    9.685883
#
#                             Battery Park City-Lower Manhattan   Bay Ridge  \
# Lead                                                19.388024   26.101691
# WATER LEAK                                          34.975983  279.063246
# Bus Stop Shelter Placement                           1.779416    2.695809
# Found Property                                      11.842338    1.173234
# For Hire Vehicle Complaint                          38.223544   12.674389
#
#                             Bayside-Bayside Hills            ...             \
# Lead                                    12.538724            ...
# WATER LEAK                              41.986327            ...
# Bus Stop Shelter Placement               1.041111            ...
# Found Property                           0.315869            ...
# For Hire Vehicle Complaint               9.424493            ...
#
#                             Williamsbridge-Olinville  Williamsburg  \
# Lead                                        9.760725      3.017439
# WATER LEAK                                276.839023    120.498974
# Bus Stop Shelter Placement                  1.418393      0.526122
# Found Property                              0.787743      1.696356
# For Hire Vehicle Complaint                 11.069373     12.364101
#
#                             Windsor Terrace   Woodhaven  Woodlawn-Wakefield  \
# Lead                               7.200958   10.133781            7.956403
# WATER LEAK                        57.187734  168.500145          148.430092
# Bus Stop Shelter Placement         0.678636    1.198348            1.056407
# Found Property                     0.891943    0.650802            0.647299
# For Hire Vehicle Complaint        10.147008   10.773314           10.144821
#
#                               Woodside   Yorkville  park-cemetery-etc-Bronx  \
# Lead                         10.078224   39.361682                -1.384721
# WATER LEAK                  155.608289  185.265851                11.893778
# Bus Stop Shelter Placement    1.080223    3.609504                -0.149620
# Found Property                1.135871    3.967470                 0.576600
# For Hire Vehicle Complaint   11.617608   17.680931                 9.086463
#
#                             park-cemetery-etc-Manhattan  \
# Lead                                           0.195632
# WATER LEAK                                    59.386199
# Bus Stop Shelter Placement                     0.077083
# Found Property                                 0.978185
# For Hire Vehicle Complaint                    10.294076
#
#                             park-cemetery-etc-Queens
# Lead                                       -1.612291
# WATER LEAK                                  3.658290
# Bus Stop Shelter Placement                 -0.183590
# Found Property                              0.635692
# For Hire Vehicle Complaint                  9.386829
#
# [5 rows x 190 columns]

# %% [markdown]
# Now, we are going to obtain a table that assigns to each type of request $t$, the error between the predicted and observed values:
#
# $$error(A,t)=  \frac{ \hat{S} (A,t) }{S(A,t)}-1 $$
#
# where $\hat{S}$ is the predicted number of requests in the NTA $A$ for the type of request $t$, and $S$ is the observed number of requests

# %% [markdown]
# ###PROBLEM!!
# there are many NTAs that has 0 observed requests of type $t$, then the $error(A,t)$ formula diverges.
# For now, we are going to change the formula to:
#
# $$error(A,t)=\frac{\hat{S} (A,t) - S(A,t)}{\hat{S}(A,T)}  $$

# %%
error_table=(predicted_table-observed_table)/(predicted_table)
error_table.head()
# Out:
#                             Allerton-Pelham Gardens  \
# Lead                                      -0.278307
# WATER LEAK                                 0.138176
# Bus Stop Shelter Placement                 1.000000
# Found Property                             1.000000
# For Hire Vehicle Complaint                 0.501068
#
#                             Annadale-Huguenot-Prince's Bay-Eltingville  \
# Lead                                                          0.561571
# WATER LEAK                                                    0.661769
# Bus Stop Shelter Placement                                    1.000000
# Found Property                                                1.000000
# For Hire Vehicle Complaint                                    0.882811
#
#                             Arden Heights   Astoria  Auburndale  Baisley Park  \
# Lead                             0.596264  0.163155    0.592852      0.791888
# WATER LEAK                       0.582351  0.628981    0.907865      0.343273
# Bus Stop Shelter Placement       1.000000  0.253702    1.000000      1.000000
# Found Property                   1.000000  0.456007    1.000000      1.000000
# For Hire Vehicle Complaint       1.000000 -0.830428    0.888897      0.466629
#
#                             Bath Beach  Battery Park City-Lower Manhattan  \
# Lead                          0.157337                           0.174748
# WATER LEAK                    0.129888                           0.656907
# Bus Stop Shelter Placement   -0.425977                           0.438018
# Found Property                1.000000                          -0.013313
# For Hire Vehicle Complaint   -0.135673                          -0.412742
#
#                             Bay Ridge  Bayside-Bayside Hills  \
# Lead                        -0.264286              -0.355800
# WATER LEAK                   0.172231               0.261664
# Bus Stop Shelter Placement  -0.112838               1.000000
# Found Property               0.147655               1.000000
# For Hire Vehicle Complaint  -0.577985               0.575574
#
#                                       ...             \
# Lead                                  ...
# WATER LEAK                            ...
# Bus Stop Shelter Placement            ...
# Found Property                        ...
# For Hire Vehicle Complaint            ...
#
#                             Williamsbridge-Olinville  Williamsburg  \
# Lead                                        0.385292     -0.325628
# WATER LEAK                                 -0.784431      0.834023
# Bus Stop Shelter Placement                  1.000000      1.000000
# Found Property                              1.000000      1.000000
# For Hire Vehicle Complaint                 -0.084072      0.352966
#
#                             Windsor Terrace  Woodhaven  Woodlawn-Wakefield  \
# Lead                              -3.582724   0.210561            0.120205
# WATER LEAK                         0.143173   0.519288           -0.482179
# Bus Stop Shelter Placement         1.000000   0.165518            1.000000
# Found Property                    -0.121148   1.000000            1.000000
# For Hire Vehicle Complaint         0.310141  -0.485151            0.112848
#
#                             Woodside  Yorkville  park-cemetery-etc-Bronx  \
# Lead                        0.503881   0.542702                 1.000000
# WATER LEAK                  0.588711   0.476428                 1.000000
# Bus Stop Shelter Placement  1.000000   0.168861                 1.000000
# Found Property              0.119618  -2.024598                 1.000000
# For Hire Vehicle Complaint  0.139238   0.264745                 0.559785
#
#                             park-cemetery-etc-Manhattan  \
# Lead                                           1.000000
# WATER LEAK                                     0.309604
# Bus Stop Shelter Placement                     1.000000
# Found Property                                -4.111510
# For Hire Vehicle Complaint                    -0.262862
#
#                             park-cemetery-etc-Queens
# Lead                                        1.000000
# WATER LEAK                                  1.000000
# Bus Stop Shelter Placement                  1.000000
# Found Property                              1.000000
# For Hire Vehicle Complaint                  0.147742
#
# [5 rows x 190 columns]

# %%
#save the errors table
error_table.to_csv('outputs/error_table.csv')

# %% [markdown]
# In order to indentify zones which number of requests depends not only on socio-demographic characteristics but also on NTA features, we are going to look at the error spatial distribution.

# %% [markdown]
# ##let's take a look on how is the distribution of error for just one type of request = 'noise'

# %%
noise_error=pd.DataFrame(error_table.loc['Noise'])
noise_error.reset_index(inplace=True)
noise_error.rename(columns={'index': 'ntaname', 'Noise': 'noise error'}, inplace=True)
noise_error.head()
# Out:
#                                       ntaname  noise error
# 0                     Allerton-Pelham Gardens     0.095738
# 1  Annadale-Huguenot-Prince's Bay-Eltingville     0.577337
# 2                               Arden Heights     0.246319
# 3                                     Astoria     0.076615
# 4                                  Auburndale     0.375782

# %%
import geopandas as gpd
import mplleaflet
import pysal as ps

# %%
#load the NTA geojson and merge with noise error  
nta_json = gpd.read_file('datasets/nta_census_shapefile/NTA_json.geojson')
noise_error_geo=pd.merge(nta_json,noise_error,on=['ntaname'],how='inner')
noise_error_geo.head()
# Out:
#    borocode  boroname  cartodb_id  countyfips  \
# 0         3  Brooklyn           1          47
# 1         4    Queens           2          81
# 2         2     Bronx           4           5
# 3         3  Brooklyn           5          47
# 4         2     Bronx           6           5
#
#                                             geometry ntacode  \
# 0  (POLYGON ((-73.88828531356056 40.6467224132760...    BK93
# 1  (POLYGON ((-73.76809925805176 40.5978459701096...    QN12
# 2  (POLYGON ((-73.88438994861654 40.8229673964485...    BX27
# 3  (POLYGON ((-73.88833929256353 40.6467102284149...    BK50
# 4  (POLYGON ((-73.78833349834532 40.8346671297593...    BX10
#
#                                ntaname  percent  pop_2000  pop_2010  pop_diff  \
# 0                        Starrett City     -8.7     14621     13354     -1267
# 1             Hammels-Arverne-Edgemere     16.6     31645     36885      5240
# 2                          Hunts Point      8.2     25142     27204      2062
# 3                             Canarsie     -1.6     85058     83693     -1365
# 4  Pelham Bay-Country Club-City Island     -2.1     27140     26583      -557
#
#       shape_area     shape_leng  noise error
# 0  11598945.8236   17414.781633     0.713203
# 1  61904116.8013   83820.120650     0.486097
# 2  49734670.5573   44778.618995     0.495952
# 3  82015446.6700   43701.791058     0.515884
# 4  40248130.5227  139408.564885    -0.003548

# %%
f, ax = plt.subplots(1, figsize=(10,10))
noise_error_geo.plot(column='noise error', scheme='QUANTILES', k=7, alpha=1, colormap='YlOrRd')
#mplleaflet.display(fig=f, crs=noise_error_geo.crs,tiles= ('http://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}.png','attributions'))

# %% [markdown]
# Just by watching, it seems like the spatial distribution of the error for noise requests is random (not a lot of clusters iddentified), however, a deeper exploration tell us that there are clusters of high error (darker red - purple) in the Queens area around the airport and in the Bronx.
#
# Let's see what is the MORAN's I value in this case

# %%
psGeom = ps.open('datasets/nta_census_shapefile/neighborhood_nta_census.shp', 'r')
#psGeom=ps.open('datasets/nta_census_shapefile/NTA_json.geojson')

# %%
nta_json_ids = gpd.read_file('datasets/nta_census_shapefile/NTA_json.geojson')

# %%
#weights matrix
W = ps.buildContiguity(psGeom, criterion='queen', ids=nta_json_ids['ntaname'].values.tolist())
W['West Village']
# Out:
# {u'Chinatown': 1.0,
#  u'East Village': 1.0,
#  u'Gramercy': 1.0,
#  u'Hudson Yards-Chelsea-Flatiron-Union Square': 1.0,
#  u'SoHo-TriBeCa-Civic Center-Little Italy': 1.0}

# %%
# Now we would like to standardize all the weights. This can be 
# done by specifying 'R' as the matrix transformation. Then, let's
# look again the neighbors of the West Village. All the weights
# should add up to 1.
W.transform = 'R'
W['West Village']
# Out:
# {u'Chinatown': 0.2,
#  u'East Village': 0.2,
#  u'Gramercy': 0.2,
#  u'Hudson Yards-Chelsea-Flatiron-Union Square': 0.2,
#  u'SoHo-TriBeCa-Civic Center-Little Italy': 0.2}

# %%
# Next, we're going to perform a spatial autocorrelation on the
# 'noise error'  column. We first standardize the values by subtracting
# the mean and divide by the standard deviation.

noise_error_geo2=pd.merge(nta_json_ids,noise_error,on=['ntaname'],how='outer').fillna(value=0)
mask=map(lambda x: x in (W.full()[1]),noise_error_geo2.ntaname)
noise_error_geo3=noise_error_geo2[mask]
Y = noise_error_geo3['noise error'].values
Y = (Y-Y.mean())/Y.std()
len(Y)
# Out:
# 190

# %%
sl = ps.lag_spatial(W, Y)
noise_error_geo3['w_error'] = sl
# Out:
# C:\Users\Marco\Anaconda\lib\site-packages\IPython\kernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from IPython.kernel.zmq import kernelapp as app

# %%
# Execute the Moran's I calculation
mi = ps.Moran(Y, W)
mi.I
# Out:
# 0.23858240013862544

# %%
# Check the p-value of the calculation. This has to be < 0.05 for our
# calculation to be statistically significant.

mi.p_sim
# Out:
# 0.001

# %%
import seaborn as sns

# %%
# It's time to look at the Moran Scatter Plot to inspet the results

f, ax = plt.subplots(1, figsize=(10,10))
sns.regplot(x='noise error', y='w_error', data=noise_error_geo3)
plt.axvline(0, c='k', alpha=0.5)
plt.axhline(0, c='k', alpha=0.5)
plt.show()
# Out:
# C:\Users\Marco\Anaconda\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
# Now, let's look at local indicator. Overall, we see some
# trends, but not so strong. Maybe a local indicator test
# could help us see in details how things are correlated.
# We run the Moran's LISA calculation provided by PySAL.

lisa = ps.Moran_Local(Y, W)

# %%
# Let's narrow down to those neighborhoods that are
# statistically significant.

S = lisa.p_sim < 0.05
Q = lisa.q
# Next, we'll turn those into a GeoDataFrame for visualization.
records = map(lambda x: (noise_error_geo3.iloc[x]['ntaname'], Q[x], noise_error_geo3.geometry.iloc[x]),
              [i for i,s in enumerate(S) if s])
gdata = gpd.GeoDataFrame(records, columns=('ntaname', 'quadrant', 'geometry'))
gdata.head()
# Out:
#                                 ntaname  quadrant  \
# 0                           Hunts Point         1
# 1     Battery Park City-Lower Manhattan         3
# 2  Douglas Manor-Douglaston-Little Neck         1
# 3                         East New York         1
# 4                  Fresh Meadows-Utopia         4
#
#                                             geometry
# 0  (POLYGON ((-73.88438994861654 40.8229673964485...
# 1  (POLYGON ((-74.00078295275674 40.6942865156645...
# 2  (POLYGON ((-73.71351828105992 40.7598377308308...
# 3  (POLYGON ((-73.86106295016751 40.6743429347301...
# 4  (POLYGON ((-73.7775750688206 40.73019327580699...

# %%
f, ax = plt.subplots(1, figsize=(10,10))
gdata.plot(column='quadrant', scheme='QUANTILES', k=4, alpha=1.0, colormap='Blues')

# %%
quadrantsDf=gdata[['ntaname','quadrant']]
#quadrantsDf.to_csv('Data/quadrantsDf.csv')
merged=pd.merge(noise_error_geo3,gdata,on=['ntaname'],how='inner')

# %%
# It's time to look at the Moran Scatter Plot to inspet the results
f, ax = plt.subplots(1, figsize=(10,10))
q1=merged[merged['quadrant']==1]
plt.scatter(x=q1['noise error'], y=q1['w_error'], color='#C10020',marker='o',label='high-high')
q2=merged[merged['quadrant']==2]
plt.scatter(x=q2['noise error'], y=q2['w_error'], color='#803E75',marker='o',label='low-high')
q3=merged[merged['quadrant']==3]
plt.scatter(x=q3['noise error'], y=q3['w_error'], color='#FFB300',marker='o',label='low-low')
q4=merged[merged['quadrant']==4]
plt.scatter(x=q4['noise error'], y=q4['w_error'], color='#007D34',marker='o',label='high-low')
sns.regplot(x='noise error', y='w_error', data=noise_error_geo3, color='#232C16', marker='.',
           scatter_kws={'alpha':0.1}, 
            fit_reg=True, label='not spatially autocorrelated')
plt.axvline(0, c='k', alpha=0.5)
plt.axhline(0, c='k', alpha=0.5)
plt.xlabel('noise error')
plt.ylabel('lag noise error')
ax.set_title("Lag noise error vs Noise error", fontsize=14)
ax.set_axis_bgcolor('w')
#ax.set_axis_bgcolor((1, 0, 0))
pl.plt.legend()

# %% [markdown]
# In this case, most of the point fall out the confidence interval. The map also shows that the clusters based on the error value are not too big in this case.

# %% [markdown]
# # Process Authomatization

# %%
nta_json = gpd.read_file('datasets/nta_census_shapefile/NTA_json.geojson')
psGeom = ps.open('datasets/nta_census_shapefile/neighborhood_nta_census.shp', 'r')
sp_aut_index=pd.DataFrame(index=error_table.index, columns=['morans I','p_sim'])
for typeof in error_table.index:
    type_error=pd.DataFrame(error_table.loc[typeof])
    type_error.reset_index(inplace=True)
    type_error.rename(columns={'index': 'ntaname', typeof: 'error'}, inplace=True)
    type_error_geo=pd.merge(nta_json,type_error,on=['ntaname'],how='inner')
    W = ps.buildContiguity(psGeom, criterion='queen', ids=nta_json['ntaname'].values.tolist())
    W.transform = 'R'
    type_error_geo2=pd.merge(nta_json,type_error,on=['ntaname'],how='outer').fillna(value=0)
    mask=map(lambda x: x in (W.full()[1]),type_error_geo2.ntaname)
    type_error_geo3=type_error_geo2[mask]
    Y = type_error_geo3['error'].values
    Y = (Y-Y.mean())/Y.std()
    sl = ps.lag_spatial(W, Y)
    type_error_geo3['w_error'] = sl
    mi = ps.Moran(Y, W)
    sp_aut_index.loc[typeof,'morans I']=mi.I
    sp_aut_index.loc[typeof,'p_sim']=mi.p_sim  #p value should be <0.05
# Out:
# C:\Users\Marco\Anaconda\lib\site-packages\IPython\kernel\__main__.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sp_aut_index.head()
# Out:
#                              morans I  p_sim
# Lead                         0.374006  0.001
# WATER LEAK                  0.2449103  0.002
# Bus Stop Shelter Placement   0.132091  0.005
# Found Property              0.2420908  0.001
# For Hire Vehicle Complaint  0.1518844  0.001

# %% [markdown]
# Based on the p value, we are going to filter those types of requests that are statistically significant.

# %%
spatial_analysis=sp_aut_index[sp_aut_index.p_sim<0.05]
print len(sp_aut_index), len(spatial_analysis)
# Out:
# 102 78

# %%
spatial_analysis.sort('morans I',ascending= False).head()
# Out:
#                          morans I  p_sim
# HEAT/HOT WATER          0.6217601  0.001
# Construction            0.5864066  0.001
# Taxi Complaint          0.5334489  0.001
# Street Light Condition  0.5195586  0.001
# PLUMBING                0.5138718  0.001

# %%
spatial_analysis.to_csv('outputs/phase2_spatial_autocorrelation.csv')

# %% [markdown]
# According to this analysis, the type of request 'Blocked Driveway' has the highest moran's I.

# %%
blocked_error=pd.DataFrame(error_table.loc['Blocked Driveway'])
blocked_error.reset_index(inplace=True)
blocked_error.rename(columns={'index': 'ntaname', 'Blocked Driveway': 'blocked error'}, inplace=True)
nta_json = gpd.read_file('datasets/nta_census_shapefile/NTA_json.geojson')
blocked_error_geo=pd.merge(nta_json,blocked_error,on=['ntaname'],how='inner')
blocked_error.head()
# Out:
#                                       ntaname  blocked error
# 0                     Allerton-Pelham Gardens      -0.268554
# 1  Annadale-Huguenot-Prince's Bay-Eltingville       0.716274
# 2                               Arden Heights       0.561272
# 3                                     Astoria      -0.668387
# 4                                  Auburndale       0.272413

# %%
f, ax = plt.subplots(1, figsize=(10,10))
blocked_error_geo.plot(column='blocked error', scheme='QUANTILES', k=7, alpha=1, colormap='YlOrRd')
#mplleaflet.display(fig=f, crs=noise_error_geo.crs,tiles= ('http://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}.png','attributions'))

# %% [markdown]
# Highly autocorrelated. There are clusters of high error in Manhattan and Staten Island.

# %%
W = ps.buildContiguity(psGeom, criterion='queen', ids=nta_json['ntaname'].values.tolist())
W.transform = 'R'
blocked_error_geo2=pd.merge(nta_json,blocked_error,on=['ntaname'],how='outer').fillna(value=0)
mask=map(lambda x: x in (W.full()[1]),blocked_error_geo2.ntaname)
blocked_error_geo3=blocked_error_geo2[mask]
Y = blocked_error_geo3['blocked error'].values
Y = (Y-Y.mean())/Y.std()
sl = ps.lag_spatial(W, Y)
blocked_error_geo3['w_error'] = sl
mi = ps.Moran(Y, W)
mi.I
# Out:
# C:\Users\Marco\Anaconda\lib\site-packages\IPython\kernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0.20675813960939213

# %%
f, ax = plt.subplots(1, figsize=(10,10))
sns.regplot(x='blocked error', y='w_error', data=blocked_error_geo3)
plt.axvline(0, c='k', alpha=0.5)
plt.axhline(0, c='k', alpha=0.5)
plt.show()

# %%
lisa = ps.Moran_Local(Y, W)
S = lisa.p_sim < 0.05
Q = lisa.q
# Next, we'll turn those into a GeoDataFrame for visualization.
records = map(lambda x: (blocked_error_geo3.iloc[x]['ntaname'], Q[x], blocked_error_geo3.geometry.iloc[x]),
              [i for i,s in enumerate(S) if s])
gdata = gpd.GeoDataFrame(records, columns=('ntaname', 'quadrant', 'geometry'))
gdata.head()
f, ax = plt.subplots(1, figsize=(10,10))
gdata.plot(column='quadrant', scheme='QUANTILES', k=4, alpha=1.0, colormap='YlOrRd')
#mplleaflet.display(fig=f, crs=noise_error_geo.crs,tiles= ('http://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}.png','attributions'))

# %%
quadrantsDf=gdata[['ntaname','quadrant']]
#quadrantsDf.to_csv('Data/quadrantsDf.csv')
merged=pd.merge(blocked_error_geo3,gdata,on=['ntaname'],how='inner')

# %%
# It's time to look at the Moran Scatter Plot to inspet the results
f, ax = plt.subplots(1, figsize=(10,10))
q1=merged[merged['quadrant']==1]
plt.scatter(x=q1['blocked error'], y=q1['w_error'], color='#C10020',marker='o',label='high-high')
q2=merged[merged['quadrant']==2]
plt.scatter(x=q2['blocked error'], y=q2['w_error'], color='#803E75',marker='o',label='low-high')
q3=merged[merged['quadrant']==3]
plt.scatter(x=q3['blocked error'], y=q3['w_error'], color='#FFB300',marker='o',label='low-low')
q4=merged[merged['quadrant']==4]
plt.scatter(x=q4['blocked error'], y=q4['w_error'], color='#007D34',marker='o',label='high-low')
sns.regplot(x='blocked error', y='w_error', data=blocked_error_geo3, color='#232C16', marker='.',
           scatter_kws={'alpha':0.1}, 
            fit_reg=True, label='not spatially autocorrelated')
plt.axvline(0, c='k', alpha=0.5)
plt.axhline(0, c='k', alpha=0.5)
plt.xlabel('blocked error')
plt.ylabel('lag blocked error')
ax.set_title("Lag blocked error vs blocked error", fontsize=14)
ax.set_axis_bgcolor('w')
#ax.set_axis_bgcolor((1, 0, 0))
pl.plt.legend()

# %% [markdown]
# #Step 2a
# In the cases with a high Moran's I value, we are going to perform an additional regression with Neighborhood context features. Following the formula
#
# $$\log(S(A,t)) \sim \log (\hat{S} (A,t)) +  \log(\text{ Spatial features})$$
#
# or equivalently,
#
# $$\log(S(A,t) / \hat{S} (A,t)) \sim  \log(\text{ Spatial features})$$

# %%
spatial_features=pd.read_csv('datasets/location_features2.csv').drop(['Unnamed: 0'],axis=1).fillna(value=0)
spatial_features.head()
# Out:
#                                  Neighborhood  Median House Value  Median Age  \
# 0                                     Airport                   0        0.00
# 1                     Allerton-Pelham Gardens              445200       39.70
# 2  Annadale-Huguenot-Prince's Bay-Eltingville              527900       41.60
# 3                               Arden Heights              409750       40.45
# 4                                     Astoria              637150       34.10
#
#    Median Rent  Median Income  Cars per capita  Building Density  \
# 0            0            0.0         0.000000          0.063939
# 1         1538        64702.0         1.129863          0.410404
# 2         1342        91354.5         1.858472          0.148603
# 3         1299        88864.5         1.741741          0.287016
# 4         1432        57798.0         0.422238          0.600337
#
#    Proportion of Commercial area  Proportion of retail area  \
# 0                       1.000000                   0.000825
# 1                       0.157479                   0.040692
# 2                       0.125964                   0.009717
# 3                       0.031889                   0.018930
# 4                       0.221847                   0.066577
#
#    Proportion of Office area  Proportion of Residential area  \
# 0                   0.000197                        0.000000
# 1                   0.075124                        0.842521
# 2                   0.040170                        0.874036
# 3                   0.008397                        0.968111
# 4                   0.036913                        0.778153
#
#    Inbound Commute Density  Population Density  Proportion of Tenants
# 0              7687.083553            0.000000               0.000000
# 1              6435.383106        29798.200740               0.404297
# 2              1131.370546         5607.873966               0.175620
# 3               945.898950        14161.932700               0.111384
# 4             17386.760660        54644.611210               0.829962

# %%
spatial_subset=spatial_analysis
phase2_results=pd.DataFrame(index=spatial_subset.index, columns=['R2','best_alpha'])
results={}
for typeof in phase2_results.index:
    results[typeof]={}
    #get the observed and predicted number of calls
    predicted_typeof=pd.DataFrame(predicted_table.loc[typeof]).reset_index().rename(columns={'index':'Neighborhood'})
    observed_typeof=pd.DataFrame(observed_table.loc[typeof]).reset_index().rename(columns={'index':'Neighborhood'})
    #Get X (features) and Y (labels) datasets
    log_predicted=(predicted_typeof[typeof]).replace([np.inf, -np.inf], np.nan).dropna()
    log_observed=(observed_typeof[typeof]).replace([np.inf, -np.inf], np.nan).dropna()
    predicted_typeof['log_obs/log_pred']=np.log(log_observed/log_predicted)
    pred_obs_typeof_log=predicted_typeof[['Neighborhood','log_obs/log_pred']].replace([np.inf, -np.inf], np.nan).dropna()
    complete_table=pd.merge(spatial_features,pred_obs_typeof_log, on=['Neighborhood'],how='inner')
    X_=complete_table[complete_table.columns[1:-1]].fillna(value=0)
    X=X_.copy()
    for feature in X.columns:
        X[feature]=np.log(X[feature])
    X=X.replace([np.inf, -np.inf], np.nan).fillna(value=0)
    Y=complete_table['log_obs/log_pred'].fillna(value=0).replace([np.inf, -np.inf], np.nan)
    #Split in train, validation and test sets
    kf = KFold(n=len(X), n_folds=10, shuffle=True, random_state=21)
    j=0
    for train_index, test_index in kf:
        results[typeof][j]={}
        X_tr, X_test = X.loc[train_index], X.loc[test_index]
        X_train, X_validation = train_test_split(X_tr, test_size=0.2, random_state=21)
        Y_tr, Y_test = Y.loc[train_index], Y.loc[test_index]
        Y_train, Y_validation = train_test_split(Y_tr, test_size=0.2, random_state=21)
        del X_tr
        del Y_tr
        R2_store=[]
        #Find the best parameter for the Lasso 
        for i in np.linspace(0,2,20):
            Lasso = linear_model.Lasso(fit_intercept=True,alpha=i)
            Lasso.fit(X_train,Y_train)
            R2_OS = 1 - np.var(Lasso.predict(X_validation) - Y_validation) / np.var(Y_validation)
            R2_store.append(R2_OS)
        optim_alpha=np.linspace(0,2,20)[np.where(R2_store==np.max(R2_store))[0][0]] 
        results[typeof][j]['best_alpha']=optim_alpha
        Lasso = linear_model.Lasso(fit_intercept=True,alpha=optim_alpha)
        Lasso.fit(X_train,Y_train)
        R2_OS = 1 - np.var(Lasso.predict(X_test) - Y_test) / np.var(Y_test)
        results[typeof][j]['R2']=R2_OS
        j=j+1
    #The optimal alpha is selected for training the Lasso regression with all the features
    #I'm going to take the median of the alphas on the dictionary
    R2_l=[]
    alphas=[]
    for k in results[typeof].keys():
        r2=results[typeof][k]['R2']
        if r2>=0:
            alphas.append(results[typeof][k]['best_alpha'])
        R2_l.append(r2)
    final_r2=np.mean(R2_l)
    final_alpha=np.median(alphas)
    phase2_results.loc[typeof,'R2']=final_r2
    phase2_results.loc[typeof,'best_alpha']=final_alpha
# Out:
# C:\Users\Marco\Anaconda\lib\site-packages\IPython\kernel\__main__.py:36: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
# C:\Users\Marco\Anaconda\lib\site-packages\sklearn\linear_model\coordinate_descent.py:454: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\Marco\Anaconda\lib\site-packages\sklearn\linear_model\coordinate_descent.py:466: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations
#   ConvergenceWarning)
# C:\Users\Marco\Anaconda\lib\site-packages\IPython\kernel\__main__.py:42: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator

# %%
phase2_results
# Out:
#                                                R2  best_alpha
# Lead                                     0.144454           0
# WATER LEAK                            -0.08336146   0.1052632
# Bus Stop Shelter Placement            0.007825224   0.1052632
# Found Property                         0.02611538   0.3157895
# For Hire Vehicle Complaint            -0.06529506           0
# New Tree Request                        0.2818923           0
# Consumer Complaint                      0.0903707           0
# Other Enforcement                       0.1666568           0
# General Construction/Plumbing           0.1167197           0
# Boilers                                -0.2327922   0.1052632
# GENERAL                               -0.04408846   0.1052632
# Illegal Parking                        0.02551604  0.05263158
# Request Xmas Tree Collection          -0.03403342   0.2105263
# Dirty Conditions                     -0.008641842           0
# PLUMBING                               0.02053996   0.1052632
# Noise - Residential                    -0.1557722   0.1052632
# PAINT - PLASTER                     -8.694769e-05   0.2105263
# Water Quality                          0.01715527   0.1052632
# Non-Emergency Police Matter          -0.003355557           0
# Homeless Encampment                    0.09961606   0.1052632
# Non-Residential Heat                  0.006098306   0.1052632
# Rodent                                 -0.1008837   0.1052632
# Standing Water                         0.01005491           0
# Derelict Vehicle                       0.06706066           0
# Panhandling                            -0.3284717   0.1052632
# Graffiti                                0.1368421           0
# Taxi Complaint                          0.2344382           0
# Maintenance or Facility                0.02943714           0
# HEAT/HOT WATER                          0.1519695   0.1052632
# Hazardous Materials                   -0.08882405   0.2105263
# ...                                           ...         ...
# Snow                                    0.1506608           0
# Indoor Air Quality                        0.19891   0.1052632
# Homeless Person Assistance             0.02726155  0.05263158
# Food Establishment                      0.2835342           0
# Vending                                0.04671376           0
# DOOR/WINDOW                          -0.007276184   0.1052632
# Root/Sewer/Sidewalk Condition           0.2638635           0
# Air Quality                             0.1325693           0
# Taxi Report                            -0.3710657   0.1052632
# NONCONST                              -0.06618415   0.1052632
# SAFETY                                 0.02245908           0
# Litter Basket / Request                0.02568164  0.05263158
# Investigations and Discipline (IAD)   -0.04295847   0.1052632
# ELECTRIC                               0.09356868           0
# Overgrown Tree/Branches                 0.2473273           0
# Elevator                               0.02593481   0.1052632
# PAINT/PLASTER                          -0.1013556   0.2105263
# Industrial Waste                     -0.007825755   0.2105263
# Blocked Driveway                        0.1931852           0
# Missed Collection (All Materials)      0.08173373  0.05263158
# Traffic                                0.09608028           0
# Damaged Tree                            0.2504076           0
# Street Light Condition                 0.09294825           0
# Water System                          -0.01293905   0.1052632
# GENERAL CONSTRUCTION                   0.03099903           0
# Sanitation Condition                   0.09782718           0
# Animal Abuse                           -0.1864497  0.05263158
# Asbestos                              -0.05869936   0.1052632
# Illegal Tree Damage                     0.1211024           0
# Special Enforcement                    0.02947509           0
#
# [78 rows x 2 columns]

# %% [markdown]
# To do: run the regressions for the types of complains with R squares greater than 0.2, and with the whole set as training. Get results, analyze.

# %%
phase2_filtered=phase2_results[phase2_results['R2']>=0.1]
len(phase2_filtered)
# Out:
# 22

# %%
phase2_coefficients=pd.DataFrame(index=phase2_filtered.index,columns=list(X.columns)+['R2 os']) #table to store the coefficients of Lasso
phase2_log_predictions=pd.DataFrame(index=phase2_filtered.index, columns=spatial_features['Neighborhood']) #table with the prediction of calls
for typeof in phase2_filtered.index:
    predicted_typeof=pd.DataFrame(predicted_table.loc[typeof]).reset_index().rename(columns={'index':'Neighborhood'})
    observed_typeof=pd.DataFrame(observed_table.loc[typeof]).reset_index().rename(columns={'index':'Neighborhood'})
    #Get X (features) and Y (labels) datasets
    log_predicted=(predicted_typeof[typeof]).replace([np.inf, -np.inf], np.nan).dropna()
    log_observed=(observed_typeof[typeof]).replace([np.inf, -np.inf], np.nan).dropna()
    predicted_typeof['log_obs/log_pred']=np.log(log_observed/log_predicted)
    pred_obs_typeof_log=predicted_typeof[['Neighborhood','log_obs/log_pred']].replace([np.inf, -np.inf], np.nan).dropna()
    complete_table=pd.merge(spatial_features,pred_obs_typeof_log, on=['Neighborhood'],how='inner')
    X_=complete_table[complete_table.columns[1:-1]].fillna(value=0)
    X=X_.copy()
    for feature in X.columns:
        X[feature]=np.log(X[feature])
    X=X.replace([np.inf, -np.inf], np.nan).fillna(value=0)
    Y=complete_table['log_obs/log_pred'].fillna(value=0).replace([np.inf, -np.inf], np.nan)    
    Lasso = linear_model.Lasso(fit_intercept=True,alpha=phase2_results.loc[typeof,'best_alpha'])
    Lasso.fit(X,Y)
    myfeat=X.columns[abs(Lasso.coef_)>0]
    X=complete_table[myfeat].fillna(value=0)
    if len(X.columns)!=0:
        ordinary_LS=sm.OLS(Y, statsmodels.tools.add_constant(X)).fit()
        rsq=ordinary_LS.rsquared
        table=ordinary_LS.conf_int()
        table['std_dv']=(table[1]-table[0])/4
        table['coef']=ordinary_LS.params
        table.drop([0,1],inplace=True,axis=1) 
        phase2_coefficients.loc[typeof,'R2 os']="%.3f"%phase2_filtered.loc[typeof,'R2']
        product=1
        for variable in table.index:
            coeff_value=table.loc[variable,'coef']
            coeff_std=table.loc[variable,'std_dv']
            val_coef="%.8f +/- %.8f" % (coeff_value, coeff_std)
            phase2_coefficients.loc[typeof,variable]=val_coef
            if variable!='const':
                product=product*(X[variable]**coeff_value)
        new_table=pd.DataFrame(index=complete_table['Neighborhood'],columns=['Prediction'])
        new_table['Prediction']=(np.array(product*np.exp(ordinary_LS.params['const'])))
        for neighb in new_table.index:
            phase2_log_predictions.loc[typeof,neighb]=new_table.loc[neighb,'Prediction']*predicted_table.loc[typeof,neighb]
# Out:
# C:\Users\Marco\Anaconda\lib\site-packages\IPython\kernel\__main__.py:19: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator

# %%
phase2_coefficients.fillna(value=0,inplace=True)
phase2_coefficients
# Out:
#                                       Median House Value  \
# Lead                           0.00000085 +/- 0.00000036
# New Tree Request               0.00000349 +/- 0.00000046
# Other Enforcement              0.00000180 +/- 0.00000033
# General Construction/Plumbing  0.00000165 +/- 0.00000034
# Graffiti                       0.00000148 +/- 0.00000050
# Taxi Complaint                 0.00000013 +/- 0.00000049
# HEAT/HOT WATER                                         0
# Noise                          0.00000103 +/- 0.00000024
# Construction                                           0
# HEATING                                                0
# Sidewalk Condition             0.00000164 +/- 0.00000036
# Dead Tree                      0.00000242 +/- 0.00000040
# Street Condition               0.00000096 +/- 0.00000025
# Snow                           0.00000090 +/- 0.00000031
# Indoor Air Quality                                     0
# Food Establishment             0.00000125 +/- 0.00000040
# Root/Sewer/Sidewalk Condition  0.00000215 +/- 0.00000045
# Air Quality                    0.00000137 +/- 0.00000042
# Overgrown Tree/Branches        0.00000174 +/- 0.00000037
# Blocked Driveway               0.00000054 +/- 0.00000041
# Damaged Tree                   0.00000201 +/- 0.00000033
# Illegal Tree Damage            0.00000158 +/- 0.00000039
#
#                                                Median Age  \
# Lead                           -0.01269008 +/- 0.01117613
# New Tree Request               -0.00611463 +/- 0.01372496
# Other Enforcement              -0.04188207 +/- 0.00976464
# General Construction/Plumbing  -0.01381263 +/- 0.00985262
# Graffiti                       -0.04481406 +/- 0.01457279
# Taxi Complaint                  0.00032477 +/- 0.01437584
# HEAT/HOT WATER                                          0
# Noise                                                   0
# Construction                                            0
# HEATING                                                 0
# Sidewalk Condition             -0.01557901 +/- 0.01060319
# Dead Tree                      -0.00769467 +/- 0.01167132
# Street Condition               -0.02118738 +/- 0.00734859
# Snow                           -0.02852506 +/- 0.00910589
# Indoor Air Quality                                      0
# Food Establishment              0.02644641 +/- 0.01156830
# Root/Sewer/Sidewalk Condition  -0.00989344 +/- 0.01424260
# Air Quality                    -0.00962855 +/- 0.01267829
# Overgrown Tree/Branches        -0.05075763 +/- 0.01092345
# Blocked Driveway               -0.02542665 +/- 0.01201110
# Damaged Tree                   -0.03561360 +/- 0.00956633
# Illegal Tree Damage            -0.01118958 +/- 0.01099617
#
#                                               Median Rent  \
# Lead                           -0.00007434 +/- 0.00029186
# New Tree Request                0.00039096 +/- 0.00035868
# Other Enforcement              -0.00028989 +/- 0.00025230
# General Construction/Plumbing  -0.00009490 +/- 0.00026270
# Graffiti                        0.00075321 +/- 0.00038855
# Taxi Complaint                  0.00022001 +/- 0.00039466
# HEAT/HOT WATER                                          0
# Noise                                                   0
# Construction                                            0
# HEATING                                                 0
# Sidewalk Condition             -0.00046520 +/- 0.00027935
# Dead Tree                       0.00019230 +/- 0.00031119
# Street Condition               -0.00041570 +/- 0.00019593
# Snow                           -0.00011739 +/- 0.00024279
# Indoor Air Quality                                      0
# Food Establishment              0.00007690 +/- 0.00030844
# Root/Sewer/Sidewalk Condition   0.00081718 +/- 0.00034244
# Air Quality                     0.00028652 +/- 0.00032759
# Overgrown Tree/Branches         0.00066282 +/- 0.00028779
# Blocked Driveway                0.00212837 +/- 0.00031815
# Damaged Tree                    0.00070061 +/- 0.00025203
# Illegal Tree Damage             0.00053129 +/- 0.00028894
#
#                                             Median Income  \
# Lead                            0.00000508 +/- 0.00000417
# New Tree Request               -0.00002024 +/- 0.00000518
# Other Enforcement               0.00000063 +/- 0.00000365
# General Construction/Plumbing  -0.00000427 +/- 0.00000378
# Graffiti                       -0.00001877 +/- 0.00000560
# Taxi Complaint                  0.00001846 +/- 0.00000552
# HEAT/HOT WATER                                          0
# Noise                           0.00000068 +/- 0.00000168
# Construction                                            0
# HEATING                                                 0
# Sidewalk Condition              0.00000710 +/- 0.00000403
# Dead Tree                      -0.00000742 +/- 0.00000448
# Street Condition                0.00000344 +/- 0.00000282
# Snow                            0.00000154 +/- 0.00000350
# Indoor Air Quality                                      0
# Food Establishment              0.00000005 +/- 0.00000444
# Root/Sewer/Sidewalk Condition  -0.00002154 +/- 0.00000492
# Air Quality                     0.00000392 +/- 0.00000474
# Overgrown Tree/Branches        -0.00001002 +/- 0.00000415
# Blocked Driveway               -0.00002479 +/- 0.00000460
# Damaged Tree                   -0.00001382 +/- 0.00000363
# Illegal Tree Damage            -0.00000779 +/- 0.00000420
#
#                                           Cars per capita  \
# Lead                           -0.12307112 +/- 0.40383403
# New Tree Request               -0.51099539 +/- 0.45663826
# Other Enforcement              -0.60333108 +/- 0.32025544
# General Construction/Plumbing   0.27264894 +/- 0.32326683
# Graffiti                       -0.28980640 +/- 0.47813696
# Taxi Complaint                 -0.49056996 +/- 0.47366244
# HEAT/HOT WATER                                          0
# Noise                                                   0
# Construction                    1.57642797 +/- 0.30272422
# HEATING                                                 0
# Sidewalk Condition             -0.50753463 +/- 0.34273641
# Dead Tree                       0.77955209 +/- 0.38293890
# Street Condition               -0.06572079 +/- 0.24110902
# Snow                            0.41720324 +/- 0.29876661
# Indoor Air Quality                                      0
# Food Establishment              0.27062447 +/- 0.37955883
# Root/Sewer/Sidewalk Condition   1.35907646 +/- 0.43214498
# Air Quality                    -0.74279960 +/- 0.41581597
# Overgrown Tree/Branches         0.31768081 +/- 0.35308844
# Blocked Driveway               -0.38416223 +/- 0.39603396
# Damaged Tree                   -0.00124631 +/- 0.30922105
# Illegal Tree Damage             0.30296607 +/- 0.35527603
#
#                                          Building Density  \
# Lead                            1.78356541 +/- 0.63056056
# New Tree Request                0.92065698 +/- 0.76516113
# Other Enforcement               0.11701759 +/- 0.53671363
# General Construction/Plumbing   1.31818310 +/- 0.52644859
# Graffiti                        1.60271116 +/- 0.77865870
# Taxi Complaint                  0.58719430 +/- 0.77294559
# HEAT/HOT WATER                                          0
# Noise                                                   0
# Construction                                            0
# HEATING                                                 0
# Sidewalk Condition              1.00691563 +/- 0.55826148
# Dead Tree                      -0.59449218 +/- 0.62362613
# Street Condition               -0.36727115 +/- 0.39265242
# Snow                            0.33671609 +/- 0.48654933
# Indoor Air Quality                                      0
# Food Establishment              0.47616958 +/- 0.61812161
# Root/Sewer/Sidewalk Condition   2.58282808 +/- 0.73975097
# Air Quality                    -0.75293178 +/- 0.69686277
# Overgrown Tree/Branches         0.73341072 +/- 0.57512325
# Blocked Driveway                1.65575617 +/- 0.63758292
# Damaged Tree                   -0.23366781 +/- 0.50367046
# Illegal Tree Damage            -0.23298454 +/- 0.58092899
#
#                               Proportion of Commercial area  \
# Lead                              0.88270118 +/- 1.11380636
# New Tree Request                  3.18311300 +/- 1.44470477
# Other Enforcement                -3.21900735 +/- 1.01309208
# General Construction/Plumbing    -0.55712011 +/- 1.04975341
# Graffiti                          0.95386967 +/- 1.55266751
# Taxi Complaint                    0.48560853 +/- 1.50951552
# HEAT/HOT WATER                                            0
# Noise                                                     0
# Construction                                              0
# HEATING                                                   0
# Sidewalk Condition               -0.78728796 +/- 1.11283206
# Dead Tree                         2.12334832 +/- 1.24352818
# Street Condition                 -0.76710410 +/- 0.78296005
# Snow                             -0.64622712 +/- 0.97019315
# Indoor Air Quality                                        0
# Food Establishment               -1.78181296 +/- 1.23255200
# Root/Sewer/Sidewalk Condition     2.80230530 +/- 1.35706295
# Air Quality                      -1.33365794 +/- 1.31538704
# Overgrown Tree/Branches           1.32460562 +/- 1.14644413
# Blocked Driveway                 -0.35324047 +/- 1.27141770
# Damaged Tree                      1.45672386 +/- 1.00401094
# Illegal Tree Damage              -0.16541319 +/- 1.14160390
#
#                                 Proportion of retail area  \
# Lead                           -3.25486393 +/- 1.77661590
# New Tree Request                0.64628689 +/- 2.25249994
# Other Enforcement               6.56081249 +/- 1.58553832
# General Construction/Plumbing   3.93814542 +/- 1.64862714
# Graffiti                        9.79905670 +/- 2.43844866
# Taxi Complaint                  3.80563578 +/- 2.45433704
# HEAT/HOT WATER                                          0
# Noise                                                   0
# Construction                                            0
# HEATING                                                 0
# Sidewalk Condition              2.58069473 +/- 1.75431822
# Dead Tree                      -2.44198660 +/- 1.95294846
# Street Condition                2.15703345 +/- 1.22963087
# Snow                            1.31063211 +/- 1.52367856
# Indoor Air Quality                                      0
# Food Establishment              8.68093465 +/- 1.93571048
# Root/Sewer/Sidewalk Condition   4.50659904 +/- 2.15417870
# Air Quality                     3.62855722 +/- 2.05864463
# Overgrown Tree/Branches         3.61727272 +/- 1.80730579
# Blocked Driveway                3.67097434 +/- 2.00358164
# Damaged Tree                    1.47253930 +/- 1.58276775
# Illegal Tree Damage             7.56498047 +/- 2.04115158
#
#                                 Proportion of Office area  \
# Lead                           -2.93935487 +/- 0.91939825
# New Tree Request               -1.41705184 +/- 1.16859776
# Other Enforcement               0.02822423 +/- 0.82034745
# General Construction/Plumbing  -0.24469809 +/- 0.81227618
# Graffiti                       -1.81007598 +/- 1.20142008
# Taxi Complaint                 -3.32739869 +/- 1.16965226
# HEAT/HOT WATER                                          0
# Noise                                                   0
# Construction                   -3.22517977 +/- 3.34785474
# HEATING                                                 0
# Sidewalk Condition             -0.46596440 +/- 0.86211683
# Dead Tree                      -1.50193996 +/- 0.96221484
# Street Condition                0.42929086 +/- 0.60583733
# Snow                           -1.14155367 +/- 0.75071420
# Indoor Air Quality                                      0
# Food Establishment              0.38142911 +/- 0.95372172
# Root/Sewer/Sidewalk Condition  -3.59462858 +/- 1.11872227
# Air Quality                    -1.13500704 +/- 1.06512965
# Overgrown Tree/Branches        -2.26270404 +/- 0.88815628
# Blocked Driveway                0.01011284 +/- 0.98390476
# Damaged Tree                   -2.00150010 +/- 0.77781254
# Illegal Tree Damage            -1.33931211 +/- 0.88821865
#
#                               Proportion of Residential area  \
# Lead                               0.55045215 +/- 1.04543988
# New Tree Request                   3.30133009 +/- 1.36725391
# Other Enforcement                 -2.42847226 +/- 0.95919736
# General Construction/Plumbing     -0.36802713 +/- 0.99815198
# Graffiti                           0.62112184 +/- 1.47634494
# Taxi Complaint                    -1.33751350 +/- 1.42843948
# HEAT/HOT WATER                                             0
# Noise                                                      0
# Construction                                               0
# HEATING                                                    0
# Sidewalk Condition                -1.07343203 +/- 1.05859590
# Dead Tree                          1.97121667 +/- 1.18240159
# Street Condition                  -1.47730185 +/- 0.74447305
# Snow                              -0.29705811 +/- 0.92250256
# Indoor Air Quality                                         0
# Food Establishment                -2.22758019 +/- 1.17196496
# Root/Sewer/Sidewalk Condition      2.75521477 +/- 1.28203690
# Air Quality                       -1.91979790 +/- 1.24541076
# Overgrown Tree/Branches            1.97362995 +/- 1.09056982
# Blocked Driveway                   0.76073542 +/- 1.20955153
# Damaged Tree                       1.84269168 +/- 0.95507841
# Illegal Tree Damage               -0.03078973 +/- 1.08298877
#
#                                   Inbound Commute Density  \
# Lead                            0.00000046 +/- 0.00000064
# New Tree Request                0.00000051 +/- 0.00000082
# Other Enforcement              -0.00000003 +/- 0.00000058
# General Construction/Plumbing  -0.00000020 +/- 0.00000060
# Graffiti                       -0.00000059 +/- 0.00000088
# Taxi Complaint                 -0.00000090 +/- 0.00000085
# HEAT/HOT WATER                                          0
# Noise                           0.00000067 +/- 0.00000032
# Construction                   -0.00000220 +/- 0.00000312
# HEATING                                                 0
# Sidewalk Condition             -0.00000128 +/- 0.00000063
# Dead Tree                       0.00000014 +/- 0.00000071
# Street Condition               -0.00000015 +/- 0.00000044
# Snow                            0.00000045 +/- 0.00000055
# Indoor Air Quality              0.00000094 +/- 0.00000041
# Food Establishment             -0.00000162 +/- 0.00000070
# Root/Sewer/Sidewalk Condition  -0.00000028 +/- 0.00000078
# Air Quality                    -0.00000060 +/- 0.00000075
# Overgrown Tree/Branches        -0.00000052 +/- 0.00000065
# Blocked Driveway               -0.00000051 +/- 0.00000082
# Damaged Tree                    0.00000032 +/- 0.00000057
# Illegal Tree Damage             0.00000065 +/- 0.00000065
#
#                                        Population Density  \
# Lead                           -0.00001408 +/- 0.00000295
# New Tree Request               -0.00001227 +/- 0.00000375
# Other Enforcement              -0.00000775 +/- 0.00000266
# General Construction/Plumbing  -0.00000468 +/- 0.00000274
# Graffiti                       -0.00001065 +/- 0.00000405
# Taxi Complaint                  0.00000435 +/- 0.00000395
# HEAT/HOT WATER                  0.00001423 +/- 0.00000174
# Noise                                                   0
# Construction                                            0
# HEATING                         0.00001194 +/- 0.00000170
# Sidewalk Condition             -0.00000504 +/- 0.00000294
# Dead Tree                       0.00000234 +/- 0.00000324
# Street Condition               -0.00000348 +/- 0.00000204
# Snow                           -0.00000906 +/- 0.00000253
# Indoor Air Quality              0.00001089 +/- 0.00000171
# Food Establishment              0.00000206 +/- 0.00000321
# Root/Sewer/Sidewalk Condition  -0.00001808 +/- 0.00000358
# Air Quality                     0.00000306 +/- 0.00000345
# Overgrown Tree/Branches        -0.00001153 +/- 0.00000302
# Blocked Driveway               -0.00002222 +/- 0.00000335
# Damaged Tree                   -0.00000893 +/- 0.00000265
# Illegal Tree Damage            -0.00000108 +/- 0.00000305
#
#                                     Proportion of Tenants  R2 os  \
# Lead                            0.57835937 +/- 0.73156921  0.144
# New Tree Request               -2.56266413 +/- 0.86472980  0.282
# Other Enforcement              -1.59034432 +/- 0.61187466  0.167
# General Construction/Plumbing  -0.16472143 +/- 0.62891285  0.117
# Graffiti                       -1.06986367 +/- 0.93021136  0.137
# Taxi Complaint                  0.48374365 +/- 0.91162042  0.234
# HEAT/HOT WATER                                          0  0.152
# Noise                                                   0  0.149
# Construction                                            0  0.189
# HEATING                                                 0  0.147
# Sidewalk Condition             -1.06152724 +/- 0.67283204  0.133
# Dead Tree                       0.60027497 +/- 0.74500434  0.118
# Street Condition               -0.74784810 +/- 0.46907553  0.236
# Snow                            0.37232858 +/- 0.58124788  0.151
# Indoor Air Quality                                      0  0.199
# Food Establishment              0.91483627 +/- 0.73842846  0.284
# Root/Sewer/Sidewalk Condition   0.17517573 +/- 0.81944641  0.264
# Air Quality                    -0.57254559 +/- 0.79445099  0.133
# Overgrown Tree/Branches        -0.66617292 +/- 0.69315431  0.247
# Blocked Driveway               -1.06641954 +/- 0.77251987  0.193
# Damaged Tree                   -1.15668107 +/- 0.60703744  0.250
# Illegal Tree Damage            -0.21294514 +/- 0.69968117  0.121
#
#                                                     const
# Lead                           -1.21190263 +/- 1.57669901
# New Tree Request               -2.44435353 +/- 2.02176917
# Other Enforcement               4.77059231 +/- 1.42094201
# General Construction/Plumbing  -0.50194467 +/- 1.43976131
# Graffiti                        0.11862616 +/- 2.12951973
# Taxi Complaint                 -1.73766876 +/- 2.07543922
# HEAT/HOT WATER                 -1.07465192 +/- 0.09099632
# Noise                          -0.90416731 +/- 0.11187706
# Construction                   -1.88408293 +/- 0.29882928
# HEATING                        -0.95019670 +/- 0.08929539
# Sidewalk Condition              1.35292608 +/- 1.52992573
# Dead Tree                      -3.58629064 +/- 1.70552792
# Street Condition                2.50017442 +/- 1.07384799
# Snow                            0.56837106 +/- 1.33064256
# Indoor Air Quality             -0.95954366 +/- 0.08843290
# Food Establishment             -1.34727201 +/- 1.69047384
# Root/Sewer/Sidewalk Condition  -5.20147658 +/- 1.93387319
# Air Quality                     1.43266168 +/- 1.84493469
# Overgrown Tree/Branches        -1.06376304 +/- 1.57613573
# Blocked Driveway               -0.50266919 +/- 1.75446083
# Damaged Tree                   -0.55688378 +/- 1.38031805
# Illegal Tree Damage            -1.00884091 +/- 1.57192662

# %%
phase2_log_predictions
# Out:
# Neighborhood                  Airport Allerton-Pelham Gardens  \
# Lead                              NaN                 2230969
# New Tree Request                  NaN                0.238061
# Other Enforcement                 NaN             0.003056954
# General Construction/Plumbing     NaN            0.0003988028
# Graffiti                          NaN            9.620847e-12
# Taxi Complaint                    NaN              0.03293992
# HEAT/HOT WATER                    NaN                105.9826
# Noise                             NaN                42.53691
# Construction                      NaN                16497.56
# HEATING                           NaN                82.81482
# Sidewalk Condition                NaN               0.2856358
# Dead Tree                         NaN                3339.485
# Street Condition                  NaN                28.23192
# Snow                              NaN                 66.9557
# Indoor Air Quality                NaN                6.669451
# Food Establishment                NaN            3.178564e-11
# Root/Sewer/Sidewalk Condition     NaN            6.899148e-07
# Air Quality                       NaN               0.8623524
# Overgrown Tree/Branches           NaN              0.00575132
# Blocked Driveway                  NaN             0.001349015
# Damaged Tree                      NaN                17.57589
# Illegal Tree Damage               NaN            6.947037e-09
#
# Neighborhood                  Annadale-Huguenot-Prince's Bay-Eltingville  \
# Lead                                                        1.475063e+08
# New Tree Request                                               0.3127437
# Other Enforcement                                           1.189086e-06
# General Construction/Plumbing                               6.403919e-07
# Graffiti                                                    5.707701e-18
# Taxi Complaint                                              0.0001062676
# HEAT/HOT WATER                                                   35.0113
# Noise                                                           48.85536
# Construction                                                         NaN
# HEATING                                                         12.05489
# Sidewalk Condition                                            0.00694079
# Dead Tree                                                       409266.3
# Street Condition                                                 3.45813
# Snow                                                            17.17632
# Indoor Air Quality                                              4.283345
# Food Establishment                                          3.870728e-17
# Root/Sewer/Sidewalk Condition                               9.577234e-10
# Air Quality                                                   0.02335733
# Overgrown Tree/Branches                                     0.0001327027
# Blocked Driveway                                            2.731711e-06
# Damaged Tree                                                    24.80416
# Illegal Tree Damage                                         6.761215e-13
#
# Neighborhood                  Arden Heights       Astoria    Auburndale  \
# Lead                           9.570614e+08  7.274886e+07  1.478522e+07
# New Tree Request                  0.4361137      1.997083     0.6195357
# Other Enforcement                0.01264584    0.04356605   0.001857896
# General Construction/Plumbing  6.437306e-05   0.007512523  0.0002489174
# Graffiti                        8.49374e-14  2.865528e-08   8.30921e-12
# Taxi Complaint                          NaN      17.20329     0.1093381
# HEAT/HOT WATER                     24.65524      573.2945      39.59736
# Noise                              34.91902      248.6207       47.3504
# Construction                            NaN      102171.2      562817.9
# HEATING                            4.896898      487.8464       25.4186
# Sidewalk Condition                0.6737224      2.446827     0.2908925
# Dead Tree                          27391.96      1986.198      12103.18
# Street Condition                   19.58652       39.4601       19.7437
# Snow                               584.7434      328.3753      111.0627
# Indoor Air Quality                 5.086765      17.49142      5.221412
# Food Establishment             5.887347e-14   3.33008e-09  6.218784e-12
# Root/Sewer/Sidewalk Condition  7.353941e-07  7.424242e-05  3.713748e-06
# Air Quality                        6.807204      16.59809      1.294112
# Overgrown Tree/Branches          0.02288453    0.09650232    0.01797938
# Blocked Driveway               0.0002495619    0.02431133  0.0006438652
# Damaged Tree                        368.021      60.19814      77.23979
# Illegal Tree Damage            8.841991e-10  1.018867e-06  8.898021e-09
#
# Neighborhood                   Baisley Park    Bath Beach  \
# Lead                           4.444791e+09  4.689069e+07
# New Tree Request                   4.036524     0.3144109
# Other Enforcement              0.0004291477   0.005973779
# General Construction/Plumbing  0.0001229937  0.0009151641
# Graffiti                       1.245924e-11  1.334831e-10
# Taxi Complaint                     11.49868     0.9230756
# HEAT/HOT WATER                     126.4756      144.6913
# Noise                              24.29702       56.7305
# Construction                   8.602459e+07      198000.4
# HEATING                            105.0942      119.1742
# Sidewalk Condition                0.2861825     0.6277036
# Dead Tree                          285083.4      4632.468
# Street Condition                    6.15991      17.44142
# Snow                               681.2739      208.7307
# Indoor Air Quality                 6.117053      7.120481
# Food Establishment             3.706689e-13  7.440049e-11
# Root/Sewer/Sidewalk Condition  0.0002567799  1.285911e-05
# Air Quality                        4.119091       3.04975
# Overgrown Tree/Branches           0.2957312    0.02819781
# Blocked Driveway               0.0003400547   0.002583017
# Damaged Tree                       1450.552      45.15578
# Illegal Tree Damage            9.523497e-09  3.491094e-08
#
# Neighborhood                  Battery Park City-Lower Manhattan     Bay Ridge  \
# Lead                                                   427494.3  3.181119e+07
# New Tree Request                                     0.01932094     0.4793175
# Other Enforcement                                  0.0002723666    0.01044018
# General Construction/Plumbing                      0.0002585353   0.001461364
# Graffiti                                           4.062523e-13  2.313763e-10
# Taxi Complaint                                       0.01148058     0.5130365
# HEAT/HOT WATER                                          133.376      458.0701
# Noise                                                  407.7689      192.7318
# Construction                                                NaN      30237.74
# HEATING                                                73.54128      373.4488
# Sidewalk Condition                                    0.5603797      0.689785
# Dead Tree                                              62.13869      7163.754
# Street Condition                                       55.29085      42.47714
# Snow                                                   2.056718      212.0598
# Indoor Air Quality                                     14.85845      13.52742
# Food Establishment                                 1.090205e-10  1.802407e-10
# Root/Sewer/Sidewalk Condition                      1.368477e-10  5.454886e-06
# Air Quality                                           0.2650921      3.989721
# Overgrown Tree/Branches                            4.165635e-06    0.02716833
# Blocked Driveway                                   3.804906e-05   0.005088639
# Damaged Tree                                         0.02838753      49.97597
# Illegal Tree Damage                                8.599871e-11  7.181653e-08
#
# Neighborhood                                ...               Windsor Terrace  \
# Lead                                        ...                  7.689499e+10
# New Tree Request                            ...                      2.584025
# Other Enforcement                           ...                  6.897265e-05
# General Construction/Plumbing               ...                  0.0001135671
# Graffiti                                    ...                  4.751976e-12
# Taxi Complaint                              ...                      34.46978
# HEAT/HOT WATER                              ...                      99.92454
# Noise                                       ...                      86.89429
# Construction                                ...                           NaN
# HEATING                                     ...                      78.66086
# Sidewalk Condition                          ...                     0.3260606
# Dead Tree                                   ...                      196084.9
# Street Condition                            ...                      1.720897
# Snow                                        ...                      502.0937
# Indoor Air Quality                          ...                      7.637519
# Food Establishment                          ...                  1.314046e-13
# Root/Sewer/Sidewalk Condition               ...                  0.0002815703
# Air Quality                                 ...                      2.091655
# Overgrown Tree/Branches                     ...                    0.09733837
# Blocked Driveway                            ...                  0.0001686448
# Damaged Tree                                ...                      383.4394
# Illegal Tree Damage                         ...                  1.888323e-09
#
# Neighborhood                      Woodhaven Woodlawn-Wakefield      Woodside  \
# Lead                           2.953417e+08       4.479573e+08   8.27013e+07
# New Tree Request                   1.972484          0.7476485      1.984313
# Other Enforcement                0.01675573        0.001141956   0.003096827
# General Construction/Plumbing   0.001875053       0.0003309221    0.00147011
# Graffiti                       1.491955e-09       2.176985e-11  1.118249e-09
# Taxi Complaint                     11.49577           1.701951      4.728455
# HEAT/HOT WATER                     258.8499           212.2581       246.398
# Noise                               47.0912            51.7037      94.92841
# Construction                        7575901           875523.6      281277.4
# HEATING                            216.7663           178.6155      208.1083
# Sidewalk Condition                 1.139032          0.3457649     0.7461015
# Dead Tree                          22483.05           35436.03      8375.664
# Street Condition                   25.01847           10.34415      16.49619
# Snow                               782.6833           337.5459      194.0661
# Indoor Air Quality                  8.26903           7.650335      9.852673
# Food Establishment             1.169897e-10        4.97707e-12   1.57353e-10
# Root/Sewer/Sidewalk Condition  0.0004307547       3.001893e-05  7.131244e-05
# Air Quality                        10.76745           2.300791       3.62719
# Overgrown Tree/Branches           0.4359765         0.05645148    0.06732283
# Blocked Driveway                0.006108253        0.001033064    0.00458489
# Damaged Tree                         507.72           155.2906      81.82119
# Illegal Tree Damage            2.567106e-07       9.935402e-09  9.016952e-08
#
# Neighborhood                      Yorkville park-cemetery-etc-Bronx  \
# Lead                           9.527262e+09                     NaN
# New Tree Request                   2.001639                     NaN
# Other Enforcement               0.003873353                     NaN
# General Construction/Plumbing   0.001302717            1.048423e-10
# Graffiti                       1.004948e-10            4.222291e-25
# Taxi Complaint                     20.96897            8.317884e-08
# HEAT/HOT WATER                     398.9186                14.99793
# Noise                              584.0839                13.75915
# Construction                            NaN                     NaN
# HEATING                            283.9415                15.89874
# Sidewalk Condition                 2.156102            6.612796e-06
# Dead Tree                          11290.06                601726.6
# Street Condition                   10.99039               0.2508082
# Snow                               365.1416              0.06088779
# Indoor Air Quality                 25.02364                4.990256
# Food Establishment             1.456054e-11            6.255671e-21
# Root/Sewer/Sidewalk Condition  1.602258e-05                     NaN
# Air Quality                        9.043668                     NaN
# Overgrown Tree/Branches          0.03040462            9.250027e-10
# Blocked Driveway                0.002393274             5.18033e-11
# Damaged Tree                       61.89213              0.01897157
# Illegal Tree Damage            1.471907e-08            9.701823e-18
#
# Neighborhood                  park-cemetery-etc-Brooklyn  \
# Lead                                                 NaN
# New Tree Request                                     NaN
# Other Enforcement                                    NaN
# General Construction/Plumbing                        NaN
# Graffiti                                             NaN
# Taxi Complaint                                       NaN
# HEAT/HOT WATER                                       NaN
# Noise                                                NaN
# Construction                                         NaN
# HEATING                                              NaN
# Sidewalk Condition                                   NaN
# Dead Tree                                            NaN
# Street Condition                                     NaN
# Snow                                                 NaN
# Indoor Air Quality                                   NaN
# Food Establishment                                   NaN
# Root/Sewer/Sidewalk Condition                        NaN
# Air Quality                                          NaN
# Overgrown Tree/Branches                              NaN
# Blocked Driveway                                     NaN
# Damaged Tree                                         NaN
# Illegal Tree Damage                                  NaN
#
# Neighborhood                  park-cemetery-etc-Manhattan  \
# Lead                                                  NaN
# New Tree Request                                      NaN
# Other Enforcement                                       0
# General Construction/Plumbing                         NaN
# Graffiti                                              NaN
# Taxi Complaint                                        NaN
# HEAT/HOT WATER                                   84.61565
# Noise                                            27.47261
# Construction                                          inf
# HEATING                                          77.06412
# Sidewalk Condition                                    NaN
# Dead Tree                                             inf
# Street Condition                                        0
# Snow                                                  NaN
# Indoor Air Quality                               6.173672
# Food Establishment                                      0
# Root/Sewer/Sidewalk Condition                         NaN
# Air Quality                                           NaN
# Overgrown Tree/Branches                               NaN
# Blocked Driveway                                        0
# Damaged Tree                                          NaN
# Illegal Tree Damage                                   NaN
#
# Neighborhood                  park-cemetery-etc-Queens  \
# Lead                                               NaN
# New Tree Request                           0.001189165
# Other Enforcement                         7.077422e-07
# General Construction/Plumbing             5.624773e-08
# Graffiti                                  7.150996e-18
# Taxi Complaint                                2.433248
# HEAT/HOT WATER                                3.315452
# Noise                                         13.14359
# Construction                                   3615186
# HEATING                                            NaN
# Sidewalk Condition                          0.01425209
# Dead Tree                                     93816.34
# Street Condition                              12.42422
# Snow                                           8.43981
# Indoor Air Quality                            4.834557
# Food Establishment                        2.826449e-16
# Root/Sewer/Sidewalk Condition             1.916345e-11
# Air Quality                                   7.764113
# Overgrown Tree/Branches                   3.518987e-06
# Blocked Driveway                          2.017407e-09
# Damaged Tree                                  4.247008
# Illegal Tree Damage                       1.035126e-12
#
# Neighborhood                  park-cemetery-etc-Staten Island
# Lead                                                      NaN
# New Tree Request                                          NaN
# Other Enforcement                                         NaN
# General Construction/Plumbing                             NaN
# Graffiti                                                  NaN
# Taxi Complaint                                            NaN
# HEAT/HOT WATER                                            NaN
# Noise                                                     NaN
# Construction                                              NaN
# HEATING                                                   NaN
# Sidewalk Condition                                        NaN
# Dead Tree                                                 NaN
# Street Condition                                          NaN
# Snow                                                      NaN
# Indoor Air Quality                                        NaN
# Food Establishment                                        NaN
# Root/Sewer/Sidewalk Condition                             NaN
# Air Quality                                               NaN
# Overgrown Tree/Branches                                   NaN
# Blocked Driveway                                          NaN
# Damaged Tree                                              NaN
# Illegal Tree Damage                                       NaN
#
# [22 rows x 194 columns]

# %%
phase2_coefficients.to_csv('outputs/phase2_coefficients.csv')
phase2_log_predictions.to_csv('outputs/phase2_predicted.csv')
phase2_filtered.to_csv('outputs/phase2_regressions.csv')
